# %%
from p2p_analytics import fiat_comparison, intraday_profile, p2p_spread, official_premium, order_imbalance, p2p_summary, price_volatility, top_advertisers
import pandas as pd

# %%
PATH = "exports"

# %% [markdown]
# # Daily Fiat Comparison

# %%
daily_fiat_comparison = fiat_comparison(currencies=['USD', 'EUR', 'GBP', 'JPY', 'CNY', 'MXN', 'ARS', 'BOB'])
daily_fiat_comparison
daily_fiat_comparison.to_csv(f"{PATH}/daily_fiat_comparison/fiat_comparison.csv")

# %% [markdown]
# # Intraday Profile

# %%
USD_intraday_profile = intraday_profile(currency="USD")
USD_intraday_profile.to_csv(f"{PATH}/intraday_profile_by_currency/USD_intraday_profile.csv")

EUR_intraday_profile = intraday_profile(currency="EUR")
EUR_intraday_profile.to_csv(f"{PATH}/intraday_profile_by_currency/EUR_intraday_profile.csv")

GBP_intraday_profile = intraday_profile(currency="GBP")
GBP_intraday_profile.to_csv(f"{PATH}/intraday_profile_by_currency/GBP_intraday_profile.csv")

JPY_intraday_profile = intraday_profile(currency="JPY")
JPY_intraday_profile.to_csv(f"{PATH}/intraday_profile_by_currency/JPY_intraday_profile.csv")

CNY_intraday_profile = intraday_profile(currency="CNY")
CNY_intraday_profile.to_csv(f"{PATH}/intraday_profile_by_currency/CNY_intraday_profile.csv")

MXN_intraday_profile = intraday_profile(currency="MXN")
MXN_intraday_profile.to_csv(f"{PATH}/intraday_profile_by_currency/MXN_intraday_profile.csv")

ARS_intraday_profile = intraday_profile(currency="ARS")
ARS_intraday_profile.to_csv(f"{PATH}/intraday_profile_by_currency/ARS_intraday_profile.csv")

BOB_intraday_profile = intraday_profile(currency="BOB")
BOB_intraday_profile.to_csv(f"{PATH}/intraday_profile_by_currency/BOB_intraday_profile.csv")

# %% [markdown]
# # P2P Spread

# %% [markdown]
# ## By Day

# %%
USD_p2p_spread = p2p_spread(currency="USD", by='day')
USD_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/day/USD_p2p_spread.csv")

EUR_p2p_spread = p2p_spread(currency="EUR", by='day')
EUR_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/day/EUR_p2p_spread.csv")

GBP_p2p_spread = p2p_spread(currency="GBP", by='day')
GBP_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/day/GBP_p2p_spread.csv")

JPY_p2p_spread = p2p_spread(currency="JPY", by='day')
JPY_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/day/JPY_p2p_spread.csv")

CNY_p2p_spread = p2p_spread(currency="CNY", by='day')
CNY_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/day/CNY_p2p_spread.csv")

MXN_p2p_spread = p2p_spread(currency="MXN", by='day')
MXN_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/day/MXN_p2p_spread.csv")

ARS_p2p_spread = p2p_spread(currency="ARS", by='day')
ARS_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/day/ARS_p2p_spread.csv")

BOB_p2p_spread = p2p_spread(currency="BOB", by='day')
BOB_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/day/BOB_p2p_spread.csv")

# %% [markdown]
# ## By Hour

# %%
USD_p2p_spread = p2p_spread(currency="USD", by='hour')
USD_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/hour/USD_p2p_spread.csv")

EUR_p2p_spread = p2p_spread(currency="EUR", by='hour')
EUR_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/hour/EUR_p2p_spread.csv")

GBP_p2p_spread = p2p_spread(currency="GBP", by='hour')
GBP_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/hour/GBP_p2p_spread.csv")

JPY_p2p_spread = p2p_spread(currency="JPY", by='hour')
JPY_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/hour/JPY_p2p_spread.csv")

CNY_p2p_spread = p2p_spread(currency="CNY", by='hour')
CNY_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/hour/CNY_p2p_spread.csv")

MXN_p2p_spread = p2p_spread(currency="MXN", by='hour')
MXN_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/hour/MXN_p2p_spread.csv")

ARS_p2p_spread = p2p_spread(currency="ARS", by='hour')
ARS_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/hour/ARS_p2p_spread.csv")

BOB_p2p_spread = p2p_spread(currency="BOB", by='hour')
BOB_p2p_spread.to_csv(f"{PATH}/p2p_spread_by_currency/hour/BOB_p2p_spread.csv")

# %% [markdown]
# # Premium vs. Official Exchange Rate

# %%
USD_official_premium = official_premium(currency="USD", by='day')
USD_official_premium.to_csv(f"{PATH}/official_premium_by_currency/USD_official_premium.csv") #yet no data

EUR_official_premium = official_premium(currency="EUR", by='day')
EUR_official_premium.to_csv(f"{PATH}/official_premium_by_currency/EUR_official_premium.csv")

GBP_official_premium = official_premium(currency="GBP", by='day')
GBP_official_premium.to_csv(f"{PATH}/official_premium_by_currency/GBP_official_premium.csv")

JPY_official_premium = official_premium(currency="JPY", by='day')
JPY_official_premium.to_csv(f"{PATH}/official_premium_by_currency/JPY_official_premium.csv")

CNY_official_premium = official_premium(currency="CNY", by='day')
CNY_official_premium.to_csv(f"{PATH}/official_premium_by_currency/CNY_official_premium.csv")

MXN_official_premium = official_premium(currency="MXN", by='day')
MXN_official_premium.to_csv(f"{PATH}/official_premium_by_currency/MXN_official_premium.csv")

ARS_official_premium = official_premium(currency="ARS", by='day')
ARS_official_premium.to_csv(f"{PATH}/official_premium_by_currency/ARS_official_premium.csv")

BOB_official_premium = official_premium(currency="BOB", by='day')
BOB_official_premium.to_csv(f"{PATH}/official_premium_by_currency/BOB_official_premium.csv")

# %% [markdown]
# # Microstructure Indicators

# %%
USD_order_imbalance = order_imbalance(currency="USD", by='hour')
USD_order_imbalance.to_csv(f"{PATH}/order_imbalance_by_currency/USD_order_imbalance.csv")

EUR_order_imbalance = order_imbalance(currency="EUR", by='hour')
EUR_order_imbalance.to_csv(f"{PATH}/order_imbalance_by_currency/EUR_order_imbalance.csv")

GBP_order_imbalance = order_imbalance(currency="GBP", by='hour')
GBP_order_imbalance.to_csv(f"{PATH}/order_imbalance_by_currency/GBP_order_imbalance.csv")

JPY_order_imbalance = order_imbalance(currency="JPY", by='hour')
JPY_order_imbalance.to_csv(f"{PATH}/order_imbalance_by_currency/JPY_order_imbalance.csv")

CNY_order_imbalance = order_imbalance(currency="CNY", by='hour')
CNY_order_imbalance.to_csv(f"{PATH}/order_imbalance_by_currency/CNY_order_imbalance.csv")

MXN_order_imbalance = order_imbalance(currency="MXN", by='hour')
MXN_order_imbalance.to_csv(f"{PATH}/order_imbalance_by_currency/MXN_order_imbalance.csv")

ARS_order_imbalance = order_imbalance(currency="ARS", by='hour')
ARS_order_imbalance.to_csv(f"{PATH}/order_imbalance_by_currency/ARS_order_imbalance.csv")

BOB_order_imbalance = order_imbalance(currency="BOB", by='hour')
BOB_order_imbalance.to_csv(f"{PATH}/order_imbalance_by_currency/BOB_order_imbalance.csv")

# %% [markdown]
# # Summary Statistics

# %%
p2p_summary = p2p_summary(currencies=['USD', 'EUR', 'GBP', 'JPY', 'CNY', 'MXN', 'ARS', 'BOB'])
p2p_summary.to_csv(f"{PATH}/p2p_summary.csv")
p2p_summary
# Out:
#           date currency  avg_buy_price  avg_sell_price  max_buy_price  \
# 0   2025-12-07      ARS    1502.481728     1493.456489       1516.000
# 1   2025-12-08      ARS    1504.064332     1493.856204       1530.000
# 2   2025-12-09      ARS    1497.855465     1489.168346       1514.900
# 3   2025-12-10      ARS    1494.438099     1484.893806       1505.800
# 4   2025-12-07      BOB       9.530453        9.496868          9.580
# 5   2025-12-08      BOB       9.578789        9.497632         10.140
# 6   2025-12-09      BOB       9.494851        9.432916          9.600
# 7   2025-12-10      BOB       9.431891        9.361110          9.520
# 8   2025-12-07      CNY       6.979797        6.971208          7.030
# 9   2025-12-08      CNY       6.978919        6.978898          7.020
# 10  2025-12-09      CNY       6.980086        6.980583          7.010
# 11  2025-12-10      CNY       6.981000        6.980421          7.010
# ...

# %% [markdown]
# # Volatility

# %%
EUR_price_volatility = price_volatility(currency='EUR', by='day', window=7)
EUR_price_volatility.to_csv(f"{PATH}/price_volatility_by_currency/EUR_price_volatility.csv")

GBP_price_volatility = price_volatility(currency='GBP', by='day', window=7)
GBP_price_volatility.to_csv(f"{PATH}/price_volatility_by_currency/GBP_price_volatility.csv")

JPY_price_volatility = price_volatility(currency='JPY', by='day', window=7)
JPY_price_volatility.to_csv(f"{PATH}/price_volatility_by_currency/JPY_price_volatility.csv")

CNY_price_volatility = price_volatility(currency='CNY', by='day', window=7)
CNY_price_volatility.to_csv(f"{PATH}/price_volatility_by_currency/CNY_price_volatility.csv")

MXN_price_volatility = price_volatility(currency='MXN', by='day', window=7)
MXN_price_volatility.to_csv(f"{PATH}/price_volatility_by_currency/MXN_price_volatility.csv")

ARS_price_volatility = price_volatility(currency='ARS', by='day', window=7)
ARS_price_volatility.to_csv(f"{PATH}/price_volatility_by_currency/ARS_price_volatility.csv")

BOB_price_volatility = price_volatility(currency='BOB', by='day', window=7)
BOB_price_volatility.to_csv(f"{PATH}/price_volatility_by_currency/BOB_price_volatility.csv")

# %% [markdown]
# # Top Advertisers

# %%
USD_top_advertisers = top_advertisers(currency='USD')
USD_top_advertisers.to_csv(f"{PATH}/top_advertisers_by_currency/USD_top_advertisers.csv")

EUR_top_advertisers = top_advertisers(currency='EUR')
EUR_top_advertisers.to_csv(f"{PATH}/top_advertisers_by_currency/EUR_top_advertisers.csv")

GBP_top_advertisers = top_advertisers(currency='GBP')
GBP_top_advertisers.to_csv(f"{PATH}/top_advertisers_by_currency/GBP_top_advertisers.csv")

JPY_top_advertisers = top_advertisers(currency='JPY')
JPY_top_advertisers.to_csv(f"{PATH}/top_advertisers_by_currency/JPY_top_advertisers.csv")

CNY_top_advertisers = top_advertisers(currency='CNY')
CNY_top_advertisers.to_csv(f"{PATH}/top_advertisers_by_currency/CNY_top_advertisers.csv")

MXN_top_advertisers = top_advertisers(currency='MXN')
MXN_top_advertisers.to_csv(f"{PATH}/top_advertisers_by_currency/MXN_top_advertisers.csv")

ARS_top_advertisers = top_advertisers(currency='ARS')
ARS_top_advertisers.to_csv(f"{PATH}/top_advertisers_by_currency/ARS_top_advertisers.csv")

BOB_top_advertisers = top_advertisers(currency='BOB')
BOB_top_advertisers.to_csv(f"{PATH}/top_advertisers_by_currency/BOB_top_advertisers.csv")
